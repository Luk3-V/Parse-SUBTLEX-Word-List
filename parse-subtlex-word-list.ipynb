# %%
import pandas as pd

pd.set_option('mode.chained_assignment', None)

words = pd.read_csv('../input/subtlex-word-frequency/SUBTLEXfreqPoS.csv') # Words w/ their frequency & part of speech
nouns = pd.read_csv('../input/list-of-nouns/nounlist.csv', header=None) # Common singular nouns

# Drop words w/ only 1 occurrence 
lowFreq = words[words['FREQcount'] == 1].index
wordsSorted = words.drop(lowFreq)

# Sort by film frequency then alphebetically
wordsSorted.sort_values(by=['Lg10CD', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

wordsSorted
# Out:
#            Word  FREQcount  CDcount  FREQlow  Cdlow   SUBTLWF  Lg10WF  \
# 0           the    1501908     8388  1339811   8388  29449.18  6.1766
# 1            to    1156570     8383  1138435   8380  22677.84  6.0632
# 2             a    1041179     8382   976941   8380  20415.27  6.0175
# 3           you    2134713     8381  1595028   8376  41857.12  6.3293
# 4           and     682780     8379   515365   8374  13387.84  5.8343
# ...         ...        ...      ...      ...    ...       ...     ...
# 60379   zionism          2        1        2      1      0.04  0.4771
# 60380  zionists          2        1        0      0      0.04  0.4771
# 60381     zloty          2        1        2      1      0.04  0.4771
# 60382      zoon          6        1        6      1      0.12  0.8451
# 60383  zopilote          6        1        0      0      0.12  0.8451
#
#        SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0       100.00  3.9237         Article             1499459.0
# 1        99.94  3.9235              To              787798.0
# 2        99.93  3.9234         Article              993445.0
# 3        99.92  3.9233         Pronoun             2125610.0
# 4        99.89  3.9232     Conjunction              680792.0
# ...        ...     ...             ...                   ...
# 60379     0.01  0.3010            Noun                   2.0
# 60380     0.01  0.3010            Noun                   2.0
# 60381     0.01  0.3010            Noun                   2.0
# 60382     0.01  0.3010            Noun                   6.0
# 60383     0.01  0.3010            Verb                   4.0
#
#        Percentage_dom_PoS                                    All_PoS_SUBTLEX  \
# 0                    1.00          Article.Adverb.Noun.Preposition.Adjective
# 1                    0.68               To.Preposition.Adverb.Noun.Adjective
# 2                    0.96  Article.Adverb.Letter.To.Noun.Preposition.Adje...
# 3                    1.00                                       Pronoun.Noun
# 4                    1.00          Conjunction.Adverb.Interjection.Noun.Name
# ...                   ...                                                ...
# 60379                1.00                                               Noun
# 60380                1.00                                               Noun
# 60381                1.00                                               Noun
# 60382                1.00                                               Noun
# 60383                0.67                                          Verb.Name
#
#                     All_freqs_SUBTLEX
# 0               1499459.774.147.105.1
# 1             787798.366834.931.79.68
# 2      993445.33186.6441.744.257.52.5
# 3                          2125610.79
# 4                   680792.745.22.4.4
# ...                               ...
# 60379                               2
# 60380                               2
# 60381                               2
# 60382                               6
# 60383                             4.2
#
# [60384 rows x 14 columns]

# %%
# Utility functions

# Return position of substring in string list
def findPos(string, substring, delimiter):
    return string[:string.index(substring)].count(delimiter)

# Return nth value in a string list of values
def findNthVal(vals, delimiter, n):
    vals = vals + delimiter 
    index = -1
    for i in range(n): 
        index = vals.find(delimiter, index+1)
        
    return int(vals[index+1:vals.index(delimiter,index+1)])

# %% [markdown]
# ---
# # Noun Data:
# ---

# %%
# List of all nouns
nounsAll = words[words['All_PoS_SUBTLEX'].str.contains('Noun', na = False)]

# Find frequency of each word as a noun 
nounFreq = []
for i in nounsAll.index:
    n = findPos(nounsAll['All_PoS_SUBTLEX'][i], 'Noun', '.')
    nounFreq.append(findNthVal(nounsAll['All_freqs_SUBTLEX'][i], '.', n))
   
# Sort by noun frequency
nounsAll['Noun_freq'] = nounFreq
nounsAll.sort_values(by=['Noun_freq', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

nounsAll
# Out:
#                  Word  FREQcount  CDcount  FREQlow  Cdlow  SUBTLWF  Lg10WF  \
# 0                time      99890     8308    96603   8303  1958.63  4.9995
# 1                 man      94133     8054    84739   7956  1845.75  4.9737
# 2                 way      72661     8222    71259   8206  1424.73  4.8613
# 3              people      56252     7889    50482   7791  1102.98  4.7501
# 4               thing      55522     8058    55245   8057  1088.67  4.7445
# ...               ...        ...      ...      ...    ...      ...     ...
# 45465       zoroaster          1        1        0      0     0.02  0.3010
# 45466  zoroastrianism          1        1        0      0     0.02  0.3010
# 45467        zugzwang          1        1        1      1     0.02  0.3010
# 45468         zygotes          1        1        1      1     0.02  0.3010
# 45469         zymurgy          1        1        1      1     0.02  0.3010
#
#        SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0        99.05  3.9195            Noun               98420.0
# 1        96.02  3.9061            Noun               93487.0
# 2        98.02  3.9150            Noun               71592.0
# 3        94.05  3.8971            Noun               56170.0
# 4        96.07  3.9063            Noun               55460.0
# ...        ...     ...             ...                   ...
# 45465     0.01  0.3010            Noun                   1.0
# 45466     0.01  0.3010            Noun                   1.0
# 45467     0.01  0.3010            Noun                   1.0
# 45468     0.01  0.3010            Noun                   1.0
# 45469     0.01  0.3010            Noun                   1.0
#
#        Percentage_dom_PoS               All_PoS_SUBTLEX All_freqs_SUBTLEX  \
# 0                    0.99              Noun.Verb.Adverb     98420.725.656
# 1                    1.00                Noun.Verb.Name      93487.401.45
# 2                    0.99  Noun.Adverb.Preposition.Name    71592.899.94.6
# 3                    1.00                     Noun.Name           56170.2
# 4                    1.00                     Noun.Name          55460.22
# ...                   ...                           ...               ...
# 45465                1.00                          Noun                 1
# 45466                1.00                          Noun                 1
# 45467                1.00                          Noun                 1
# 45468                1.00                          Noun                 1
# 45469                1.00                          Noun                 1
#
#        Noun_freq
# 0          98420
# 1          93487
# 2          71592
# 3          56170
# 4          55460
# ...          ...
# 45465          1
# 45466          1
# 45467          1
# 45468          1
# 45469          1
#
# [45470 rows x 15 columns]

# %%
# List of all COMMON SINGULAR nouns
nounsCommon = nounsAll[nounsAll['Word'].isin(nouns[0])]

nounsCommon
# Out:
#              Word  FREQcount  CDcount  FREQlow  Cdlow  SUBTLWF  Lg10WF  \
# 0            time      99890     8308    96603   8303  1958.63  4.9995
# 1             man      94133     8054    84739   7956  1845.75  4.9737
# 2             way      72661     8222    71259   8206  1424.73  4.8613
# 3          people      56252     7889    50482   7791  1102.98  4.7501
# 4           thing      55522     8058    55245   8057  1088.67  4.7445
# ...           ...        ...      ...      ...    ...      ...     ...
# 45075   vibrissae          1        1        0      0     0.02  0.3010
# 45185   washbasin          1        1        1      1     0.02  0.3010
# 45194     wasting       1135      955     1085    928    22.25  3.0554
# 45207  waterwheel          1        1        1      1     0.02  0.3010
# 45210    waveform          1        1        1      1     0.02  0.3010
#
#        SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0        99.05  3.9195            Noun               98420.0
# 1        96.02  3.9061            Noun               93487.0
# 2        98.02  3.9150            Noun               71592.0
# 3        94.05  3.8971            Noun               56170.0
# 4        96.07  3.9063            Noun               55460.0
# ...        ...     ...             ...                   ...
# 45075     0.01  0.3010            Noun                   1.0
# 45185     0.01  0.3010            Noun                   1.0
# 45194    11.39  2.9805            Verb                1132.0
# 45207     0.01  0.3010            Noun                   1.0
# 45210     0.01  0.3010            Noun                   1.0
#
#        Percentage_dom_PoS               All_PoS_SUBTLEX All_freqs_SUBTLEX  \
# 0                    0.99              Noun.Verb.Adverb     98420.725.656
# 1                    1.00                Noun.Verb.Name      93487.401.45
# 2                    0.99  Noun.Adverb.Preposition.Name    71592.899.94.6
# 3                    1.00                     Noun.Name           56170.2
# 4                    1.00                     Noun.Name          55460.22
# ...                   ...                           ...               ...
# 45075                1.00                          Noun                 1
# 45185                1.00                          Noun                 1
# 45194                1.00           Verb.Adjective.Noun          1132.2.1
# 45207                1.00                          Noun                 1
# 45210                1.00                          Noun                 1
#
#        Noun_freq
# 0          98420
# 1          93487
# 2          71592
# 3          56170
# 4          55460
# ...          ...
# 45075          1
# 45185          1
# 45194          1
# 45207          1
# 45210          1
#
# [6189 rows x 15 columns]

# %%
# List of common nouns missing from list
nounsMissing = nouns[~nouns[0].isin(nounsAll['Word'])]

nounsMissing
# Out:
#                  0
# 0              ATM
# 1               CD
# 2              SUV
# 3               TV
# 11     abolishment
# ...            ...
# 6770  yellowjacket
# 6780      yourself
# 6784       zampone
# 6786     zebrafish
# 6799     zoot-suit
#
# [612 rows x 1 columns]

# %% [markdown]
# ---
# # Verb Data:
# ---

# %%
# List of all verbs
verbsAll = words[words['All_PoS_SUBTLEX'].str.contains('Verb', na = False)]

# Find frequency of each word as a verb 
verbFreq = []
for i in verbsAll.index:
    n = findPos(verbsAll['All_PoS_SUBTLEX'][i], 'Verb', '.')
    verbFreq.append(findNthVal(verbsAll['All_freqs_SUBTLEX'][i], '.', n))
   
# Sort by verb frequency
verbsAll['Verb_freq'] = verbFreq
verbsAll.sort_values(by=['Verb_freq', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

verbsAll
# Out:
#             Word  FREQcount  CDcount  FREQlow  Cdlow  SUBTLWF  Lg10WF  \
# 0             do     312915     8348   262536   8340  6135.59  5.4954
# 1             is     459663     8370   420989   8364  9013.00  5.6624
# 2           have     314232     8363   296664   8354  6161.41  5.4973
# 3            was     288391     8345   282414   8340  5654.73  5.4600
# 4             be     293085     8363   285000   8361  5746.76  5.4670
# ...          ...        ...      ...      ...    ...      ...     ...
# 23540        zep          5        1        0      0     0.10  0.7782
# 23541     zeroes         39       32       33     30     0.76  1.6021
# 23542  zigzagged          1        1        1      1     0.02  0.3010
# 23543     zinged          1        1        1      1     0.02  0.3010
# 23544       zink          2        2        1      1     0.04  0.4771
#
#        SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0        99.52  3.9216            Verb              629203.0
# 1        99.79  3.9228            Verb              488770.0
# 2        99.70  3.9224            Verb              332099.0
# 3        99.49  3.9215            Verb              309709.0
# 4        99.70  3.9224            Verb              292904.0
# ...        ...     ...             ...                   ...
# 23540     0.01  0.3010            Name                   4.0
# 23541     0.38  1.5185            Noun                  34.0
# 23542     0.01  0.3010            Verb                   1.0
# 23543     0.01  0.3010            Verb                   1.0
# 23544     0.02  0.4771            Verb                   1.0
#
#        Percentage_dom_PoS        All_PoS_SUBTLEX All_freqs_SUBTLEX  Verb_freq
# 0                    1.00              Verb.Noun         629203.22     629203
# 1                    1.00  Verb.Adverb.Noun.Name   488770.730.14.1     488770
# 2                    1.00              Verb.Noun        332099.104     332099
# 3                    1.00              Verb.Noun          309709.4     309709
# 4                    1.00              Verb.Noun         292904.68     292904
# ...                   ...                    ...               ...        ...
# 23540                0.80              Name.Verb               4.1          1
# 23541                0.87       Noun.Number.Verb            34.4.1          1
# 23542                1.00                   Verb                 1          1
# 23543                1.00                   Verb                 1          1
# 23544                0.50              Verb.Name               1.1          1
#
# [23545 rows x 15 columns]

# %% [markdown]
# ---
# # Adjective Data:
# ---

# %%
# List of all adjectives
adjectivesAll = words[words['All_PoS_SUBTLEX'].str.contains('Adjective', na = False)]

# Find frequency of each word as a adjective 
adjectiveFreq = []
for i in adjectivesAll.index:
    n = findPos(adjectivesAll['All_PoS_SUBTLEX'][i], 'Adjective', '.')
    adjectiveFreq.append(findNthVal(adjectivesAll['All_freqs_SUBTLEX'][i], '.', n))
   
# Sort by adjective frequency
adjectivesAll['Adjective_freq'] = adjectiveFreq
adjectivesAll.sort_values(by=['Adjective_freq', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

adjectivesAll
# Out:
#               Word  FREQcount  CDcount  FREQlow  Cdlow  SUBTLWF  Lg10WF  \
# 0             good     133117     8316    90673   8267  2610.14  5.1242
# 1            sorry      59566     7923    43411   7595  1167.96  4.7750
# 2           little      73766     8072    69783   8051  1446.39  4.8679
# 3            right     204428     8320   181467   8310  4008.39  5.3105
# 4            great      41864     7462    32689   7094   820.86  4.6219
# ...            ...        ...      ...      ...    ...      ...     ...
# 15161         zing         60       37       33     25     1.18  1.7853
# 15162     zippered          3        3        3      3     0.06  0.6021
# 15163   zombielike          1        1        1      1     0.02  0.3010
# 15164        zonal          1        1        1      1     0.02  0.3010
# 15165  zoroastrian          1        1        0      0     0.02  0.3010
#
#        SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0        99.14  3.9200       Adjective              131274.0
# 1        94.46  3.8989       Adjective               59455.0
# 2        96.23  3.9070       Adjective               46077.0
# 3        99.19  3.9202          Adverb              148137.0
# 4        88.96  3.8729       Adjective               41101.0
# ...        ...     ...             ...                   ...
# 15161     0.44  1.5798            Verb                  40.0
# 15162     0.04  0.6021            Verb                   2.0
# 15163     0.01  0.3010       Adjective                   1.0
# 15164     0.01  0.3010       Adjective                   1.0
# 15165     0.01  0.3010       Adjective                   1.0
#
#        Percentage_dom_PoS                        All_PoS_SUBTLEX  \
# 0                    0.99             Adjective.Adverb.Name.Noun
# 1                    1.00                         Adjective.Noun
# 2                    0.63  Adjective.Adverb.Determiner.Name.Noun
# 3                    0.73        Adverb.Adjective.Noun.Verb.Name
# 4                    0.98             Adjective.Adverb.Name.Noun
# ...                   ...                                    ...
# 15161                0.67               Verb.Noun.Name.Adjective
# 15162                0.67                         Verb.Adjective
# 15163                1.00                              Adjective
# 15164                1.00                              Adjective
# 15165                1.00                              Adjective
#
#                All_freqs_SUBTLEX  Adjective_freq
# 0             131274.1424.147.61          131274
# 1                        59455.2           59455
# 2         46077.23682.3524.394.1           46077
# 3      148137.41292.14475.200.76           41292
# 4                 41101.645.65.2           41101
# ...                          ...             ...
# 15161                  40.12.7.1               1
# 15162                        2.1               1
# 15163                          1               1
# 15164                          1               1
# 15165                          1               1
#
# [15166 rows x 15 columns]

# %% [markdown]
# ---
# # Adverb Data:
# ---

# %%
# List of all adverbs
adverbsAll = words[words['All_PoS_SUBTLEX'].str.contains('Adverb', na = False)]

# Find frequency of each word as a adverb 
adverbFreq = []
for i in adverbsAll.index:
    n = findPos(adverbsAll['All_PoS_SUBTLEX'][i], 'Adverb', '.')
    adverbFreq.append(findNthVal(adverbsAll['All_freqs_SUBTLEX'][i], '.', n))
   
# Sort by adverb frequency
adverbsAll['Adverb_freq'] = adverbFreq
adverbsAll.sort_values(by=['Adverb_freq', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

adverbsAll
# Out:
#              Word  FREQcount  CDcount  FREQlow  Cdlow  SUBTLWF  Lg10WF  \
# 0            just     242206     8338   193792   8309  4749.14  5.3842
# 1            here     230788     8352   201195   8343  4525.25  5.3632
# 2              so     216452     8350   128430   8325  4244.16  5.3354
# 3              up     187170     8345   184579   8342  3670.00  5.2722
# 4             now     163333     8350   103585   8303  3202.61  5.2131
# ...           ...        ...      ...      ...    ...      ...     ...
# 2697   wordlessly          2        2        0      0     0.04  0.4771
# 2698     workwise          1        1        0      0     0.02  0.3010
# 2699    worriedly          1        1        1      1     0.02  0.3010
# 2700  yesternight          1        1        1      1     0.02  0.3010
# 2701   youthfully          1        1        1      1     0.02  0.3010
#
#       SUBTLCD  Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  \
# 0       99.40  3.9211          Adverb              232666.0
# 1       99.57  3.9218          Adverb              230319.0
# 2       99.55  3.9217          Adverb              192197.0
# 3       99.49  3.9215          Adverb              172938.0
# 4       99.55  3.9217          Adverb              159745.0
# ...       ...     ...             ...                   ...
# 2697     0.02  0.4771            Name                   1.0
# 2698     0.01  0.3010          Adverb                   1.0
# 2699     0.01  0.3010          Adverb                   1.0
# 2700     0.01  0.3010          Adverb                   1.0
# 2701     0.01  0.3010          Adverb                   1.0
#
#       Percentage_dom_PoS                         All_PoS_SUBTLEX  \
# 0                   0.96              Adverb.Adjective.Noun.Name
# 1                   1.00                             Adverb.Noun
# 2                   0.89       Adverb.Conjunction.Adjective.Noun
# 3                   0.93  Adverb.Preposition.Verb.Adjective.Noun
# 4                   0.98                 Adverb.Conjunction.Noun
# ...                  ...                                     ...
# 2697                0.50                             Name.Adverb
# 2698                1.00                                  Adverb
# 2699                1.00                                  Adverb
# 2700                1.00                                  Adverb
# 2701                1.00                                  Adverb
#
#             All_freqs_SUBTLEX  Adverb_freq
# 0            232666.9038.14.2       232666
# 1                   230319.16       230319
# 2           192197.23905.23.9       192197
# 3     172938.12815.641.531.12       172938
# 4              159745.3231.14       159745
# ...                       ...          ...
# 2697                      1.1            1
# 2698                        1            1
# 2699                        1            1
# 2700                        1            1
# 2701                        1            1
#
# [2702 rows x 15 columns]

# %% [markdown]
# ---
# # Preposition Data:
# ---

# %%
# List of all prepositions
prepositionsAll = words[words['All_PoS_SUBTLEX'].str.contains('Preposition', na = False)]

# Find frequency of each word as a prepositions 
prepositionFreq = []
for i in prepositionsAll.index:
    n = findPos(prepositionsAll['All_PoS_SUBTLEX'][i], 'Preposition', '.')
    prepositionFreq.append(findNthVal(prepositionsAll['All_freqs_SUBTLEX'][i], '.', n))
   
# Sort by preposition frequency
prepositionsAll['Preposition_freq'] = prepositionFreq
prepositionsAll.sort_values(by=['Preposition_freq', 'Word'], ascending=[False, True], ignore_index=True, inplace=True)

prepositionsAll
# Out:
#           Word  FREQcount  CDcount  FREQlow  Cdlow   SUBTLWF  Lg10WF  SUBTLCD  \
# 0           of     590439     8375   573021   8372  11577.24  5.7712    99.85
# 1           in     498444     8372   473880   8369   9773.41  5.6976    99.81
# 2           to    1156570     8383  1138435   8380  22677.84  6.0632    99.94
# 3          for     351650     8374   332686   8370   6895.10  5.5461    99.83
# 4         with     257465     8351   247160   8349   5048.33  5.4107    99.56
# ..         ...        ...      ...      ...    ...       ...     ...      ...
# 198  reference        432      336      406    332      8.47  2.6365     4.01
# 199      afore         19       10       18     10      0.37  1.3010     0.12
# 200    apropos         17       16       12     11      0.33  1.2553     0.19
# 201     propos          1        1        1      1      0.02  0.3010     0.01
# 202   touching        888      732      836    702     17.41  2.9489     8.73
#
#      Lg10CD Dom_PoS_SUBTLEX  Freq_dom_PoS_SUBTLEX  Percentage_dom_PoS  \
# 0    3.9230     Preposition              553506.0                0.94
# 1    3.9229     Preposition              443510.0                0.89
# 2    3.9235              To              787798.0                0.68
# 3    3.9230     Preposition              344212.0                0.98
# 4    3.9218     Preposition              257287.0                1.00
# ..      ...             ...                   ...                 ...
# 198  2.5276            Noun                 409.0                0.95
# 199  1.0414     Conjunction                  18.0                0.95
# 200  1.2304          Adverb                  16.0                0.94
# 201  0.3010     Preposition                   1.0                1.00
# 202  2.8651            Verb                 605.0                0.69
#
#                                        All_PoS_SUBTLEX  \
# 0    Preposition.Adverb.Adjective.Conjunction.Noun....
# 1    Preposition.Adverb.Conjunction.Noun.Verb.Adjec...
# 2                 To.Preposition.Adverb.Noun.Adjective
# 3                  Preposition.Adverb.Conjunction.Noun
# 4                                     Preposition.Noun
# ..                                                 ...
# 198                         Noun.Verb.Preposition.Name
# 199                            Conjunction.Preposition
# 200                                 Adverb.Preposition
# 201                                        Preposition
# 202                         Verb.Adjective.Preposition
#
#                All_freqs_SUBTLEX  Preposition_freq
# 0    553506.34686.1413.156.19.15            553506
# 1     443510.50997.3154.67.49.39            443510
# 2        787798.366834.931.79.68            366834
# 3            344212.5287.1830.50            344212
# 4                      257287.17            257287
# ..                           ...               ...
# 198                   409.18.2.2                 2
# 199                         18.1                 1
# 200                         16.1                 1
# 201                            1                 1
# 202                    605.275.1                 1
#
# [203 rows x 15 columns]

# %% [markdown]
# ---
# ---

# %%
# Export data
wordsSorted.to_csv('SUBTLEXfreqPoS-sorted.csv',index=False)
nounsAll.to_csv('SUBTLEXfreqPoS-nouns.csv',index=False)
nounsCommon.to_csv('nounsCommon.csv',index=False)
nounsMissing.to_csv('nounsMissing.csv',index=False)
verbsAll.to_csv('SUBTLEXfreqPoS-verbs.csv',index=False)
adjectivesAll.to_csv('SUBTLEXfreqPoS-adjectives.csv',index=False)
adverbsAll.to_csv('SUBTLEXfreqPoS-adverbs.csv',index=False)
prepositionsAll.to_csv('SUBTLEXfreqPoS-prepositions.csv',index=False)
